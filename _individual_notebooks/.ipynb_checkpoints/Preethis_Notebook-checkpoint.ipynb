# %% [markdown]
# # project log
#
# ## 20-Jan-2026:
# ### Explored the https://clinicaltrials.gov/data-api/api webstie to investigate the possible functions we could write

# %%
library(httr)
library(jsonlite)

# 1. Build the URL
url <- "https://clinicaltrials.gov/api/v2/studies?query.term=diabetes&pageSize=5"

# 2. Download the data
response <- GET(url)

# 3. Convert JSON to R list
data <- fromJSON(content(response, "text"), simplifyVector = FALSE)

# 4. Look at what we got
names(data)
studies <- data$studies

# Look at the first study
studies[[1]]
# Out:
# No encoding supplied: defaulting to UTF-8.
# [1] "studies"       "nextPageToken"
# $protocolSection
# $protocolSection$identificationModule
# $protocolSection$identificationModule$nctId
# [1] "NCT04441658"
#
# $protocolSection$identificationModule$orgStudyIdInfo
# $protocolSection$identificationModule$orgStudyIdInfo$id
# [1] "DFSC-2020(CR)-02"
#
#
# $protocolSection$identificationModule$organization
# $protocolSection$identificationModule$organization$fullName
# [1] "Shanghai East Hospital"
#
# $protocolSection$identificationModule$organization$class
# [1] "OTHER"
#
#
# $protocolSection$identificationModule$briefTitle
# [1] "Efficacy and Safety of Umbilical Cord Mesenchymal Stem Cells Transplantation in Patients With Type 2 Diabetes Mellitus"
#
# $protocolSection$identificationModule$officialTitle
# [1] "Efficacy and Safety of Umbilical Cord Mesenchymal Stem Cells Transplantation in Patients With Type 2 Diabetes Mellitus"
#
#
# $protocolSection$statusModule
# $protocolSection$statusModule$statusVerifiedDate
# [1] "2020-06"
#
# $protocolSection$statusModule$overallStatus
# [1] "UNKNOWN"
#
# $protocolSection$statusModule$lastKnownStatus
# [1] "RECRUITING"
#
# $protocolSection$statusModule$expandedAccessInfo
# $protocolSection$statusModule$expandedAccessInfo$hasExpandedAccess
# [1] FALSE
#
#
# $protocolSection$statusModule$startDateStruct
# $protocolSection$statusModule$startDateStruct$date
# [1] "2020-04-10"
#
# $protocolSection$statusModule$startDateStruct$type
# [1] "ACTUAL"
#
#
# $protocolSection$statusModule$primaryCompletionDateStruct
# $protocolSection$statusModule$primaryCompletionDateStruct$date
# [1] "2022-07"
#
# $protocolSection$statusModule$primaryCompletionDateStruct$type
# [1] "ESTIMATED"
#
#
# $protocolSection$statusModule$completionDateStruct
# $protocolSection$statusModule$completionDateStruct$date
# [1] "2022-12"
#
# $protocolSection$statusModule$completionDateStruct$type
# [1] "ESTIMATED"
#
#
# $protocolSection$statusModule$studyFirstSubmitDate
# [1] "2020-06-19"
#
# $protocolSection$statusModule$studyFirstSubmitQcDate
# [1] "2020-06-19"
#
# $protocolSection$statusModule$studyFirstPostDateStruct
# $protocolSection$statusModule$studyFirstPostDateStruct$date
# [1] "2020-06-22"
#
# $protocolSection$statusModule$studyFirstPostDateStruct$type
# [1] "ACTUAL"
#
#
# $protocolSection$statusModule$lastUpdateSubmitDate
# [1] "2020-06-19"
#
# $protocolSection$statusModule$lastUpdatePostDateStruct
# $protocolSection$statusModule$lastUpdatePostDateStruct$date
# [1] "2020-06-22"
#
# $protocolSection$statusModule$lastUpdatePostDateStruct$type
# [1] "ACTUAL"
#
#
#
# $protocolSection$sponsorCollaboratorsModule
# $protocolSection$sponsorCollaboratorsModule$responsibleParty
# $protocolSection$sponsorCollaboratorsModule$responsibleParty$type
# [1] "SPONSOR"
#
#
# $protocolSection$sponsorCollaboratorsModule$leadSponsor
# $protocolSection$sponsorCollaboratorsModule$leadSponsor$name
# [1] "Shanghai East Hospital"
#
# $protocolSection$sponsorCollaboratorsModule$leadSponsor$class
# [1] "OTHER"
#
#
#
# $protocolSection$oversightModule
# $protocolSection$oversightModule$isFdaRegulatedDrug
# [1] FALSE
#
# $protocolSection$oversightModule$isFdaRegulatedDevice
# [1] FALSE
#
#
# $protocolSection$descriptionModule
# $protocolSection$descriptionModule$briefSummary
# [1] "This study is a 24-week single-center, randomized, double-blind, placebo-controlled trial. The trial includes a 3-week early screening and lifestyle education period, 6-week treatment period, and 18-week follow-up period. Chinese type 2 diabetic subjects receiving traditional hypoglycemic treatment were randomly assigned to umbilical cord mesenchymal stem cell or placebo infusion therapy to observe the efficacy and safety of umbilical cord mesenchymal stem cell infusion therapy."
#
# $protocolSection$descriptionModule$detailedDescription
# [1] "This study is a 24-week single-center, randomized, double-blind, placebo-controlled trial. The trial includes a 3-week early screening and lifestyle education period, 6-week treatment period, and 18-week follow-up period. Chinese type 2 diabetic subjects receiving traditional hypoglycemic treatment（including insulin） were randomly assigned to umbilical cord mesenchymal stem cell or placebo infusion therapy to observe the efficacy and safety of umbilical cord mesenchymal stem cell infusion therapy."
#
#
# $protocolSection$conditionsModule
# $protocolSection$conditionsModule$conditions
# $protocolSection$conditionsModule$conditions[[1]]
# [1] "Type 2 Diabetes"
#
# $protocolSection$conditionsModule$conditions[[2]]
# [1] "Mesenchymal Stem Cells"
#
#
# $protocolSection$conditionsModule$keywords
# $protocolSection$conditionsModule$keywords[[1]]
# [1] "Umbilical Cord Mesenchymal Stem Cells"
#
# $protocolSection$conditionsModule$keywords[[2]]
# [1] "Type 2 Diabetes"
#
#
#
# $protocolSection$designModule
# $protocolSection$designModule$studyType
# [1] "INTERVENTIONAL"
#
# $protocolSection$designModule$phases
# $protocolSection$designModule$phases[[1]]
# [1] "PHASE1"
#
# $protocolSection$designModule$phases[[2]]
# [1] "PHASE2"
#
#
# $protocolSection$designModule$designInfo
# $protocolSection$designModule$designInfo$allocation
# [1] "RANDOMIZED"
#
# $protocolSection$designModule$designInfo$interventionModel
# [1] "PARALLEL"
#
# $protocolSection$designModule$designInfo$primaryPurpose
# [1] "TREATMENT"
#
# $protocolSection$designModule$designInfo$maskingInfo
# $protocolSection$designModule$designInfo$maskingInfo$masking
# [1] "TRIPLE"
#
# $protocolSection$designModule$designInfo$maskingInfo$whoMasked
# $protocolSection$designModule$designInfo$maskingInfo$whoMasked[[1]]
# [1] "PARTICIPANT"
#
# $protocolSection$designModule$designInfo$maskingInfo$whoMasked[[2]]
# [1] "CARE_PROVIDER"
#
# $protocolSection$designModule$designInfo$maskingInfo$whoMasked[[3]]
# [1] "INVESTIGATOR"
#
#
#
#
# $protocolSection$designModule$enrollmentInfo
# $protocolSection$designModule$enrollmentInfo$count
# [1] 30
#
# $protocolSection$designModule$enrollmentInfo$type
# [1] "ESTIMATED"
#
#
#
# $protocolSection$armsInterventionsModule
# $protocolSection$armsInterventionsModule$armGroups
# $protocolSection$armsInterventionsModule$armGroups[[1]]
# $protocolSection$armsInterventionsModule$armGroups[[1]]$label
# [1] "experimental group"
#
# $protocolSection$armsInterventionsModule$armGroups[[1]]$type
# [1] "EXPERIMENTAL"
#
# $protocolSection$armsInterventionsModule$armGroups[[1]]$description
# [1] "The volunteers of the experimental group will be given peripheral intravenously a dose of 0.75\\*10\\^6/ kg human umbilical cord mesenchymal stem cells at 0,1,5,6 week."
#
# $protocolSection$armsInterventionsModule$armGroups[[1]]$interventionNames
# $protocolSection$armsInterventionsModule$armGroups[[1]]$interventionNames[[1]]
# [1] "Biological: Umbilical Cord Mesenchymal Stem Cells"
#
#
#
# $protocolSection$armsInterventionsModule$armGroups[[2]]
# $protocolSection$armsInterventionsModule$armGroups[[2]]$label
# [1] "control group"
#
# $protocolSection$armsInterventionsModule$armGroups[[2]]$type
# [1] "PLACEBO_COMPARATOR"
#
# $protocolSection$armsInterventionsModule$armGroups[[2]]$description
# [1] "The control group will be given the same dose of saline containing human albumin."
#
# $protocolSection$armsInterventionsModule$armGroups[[2]]$interventionNames
# $protocolSection$armsInterventionsModule$armGroups[[2]]$interventionNames[[1]]
# [1] "Biological: saline"
#
#
#
#
# $protocolSection$armsInterventionsModule$interventions
# $protocolSection$armsInterventionsModule$interventions[[1]]
# $protocolSection$armsInterventionsModule$interventions[[1]]$type
# [1] "BIOLOGICAL"
#
# $protocolSection$armsInterventionsModule$interventions[[1]]$name
# [1] "Umbilical Cord Mesenchymal Stem Cells"
#
# $protocolSection$armsInterventionsModule$interventions[[1]]$description
# [1] "human umbilical cord mesenchymal stem cells were peripheral intravenous infused to experimental group"
#
# $protocolSection$armsInterventionsModule$interventions[[1]]$armGroupLabels
# $protocolSection$armsInterventionsModule$interventions[[1]]$armGroupLabels[[1]]
# [1] "experimental group"
#
#
#
# $protocolSection$armsInterventionsModule$interventions[[2]]
# $protocolSection$armsInterventionsModule$interventions[[2]]$type
# [1] "BIOLOGICAL"
#
# $protocolSection$armsInterventionsModule$interventions[[2]]$name
# [1] "saline"
#
# $protocolSection$armsInterventionsModule$interventions[[2]]$description
# [1] "saline containing human albumin will be infused to the control group"
#
# $protocolSection$armsInterventionsModule$interventions[[2]]$armGroupLabels
# $protocolSection$armsInterventionsModule$interventions[[2]]$armGroupLabels[[1]]
# [1] "control group"
#
#
#
#
#
# $protocolSection$outcomesModule
# $protocolSection$outcomesModule$primaryOutcomes
# $protocolSection$outcomesModule$primaryOutcomes[[1]]
# $protocolSection$outcomesModule$primaryOutcomes[[1]]$measure
# [1] "The changes in HbA1C level"
#
# $protocolSection$outcomesModule$primaryOutcomes[[1]]$description
# [1] "The changes in HbA1C level after transplantation"
#
# $protocolSection$outcomesModule$primaryOutcomes[[1]]$timeFrame
# [1] "24 weeks after treatment"
#
#
#
# $protocolSection$outcomesModule$secondaryOutcomes
# $protocolSection$outcomesModule$secondaryOutcomes[[1]]
# $protocolSection$outcomesModule$secondaryOutcomes[[1]]$measure
# [1] "Reduction of insulin requirement"
#
# $protocolSection$outcomesModule$secondaryOutcomes[[1]]$description
# [1] "Reduction of insulin requirement after transplantation"
#
# $protocolSection$outcomesModule$secondaryOutcomes[[1]]$timeFrame
# [1] "24 weeks after treatment"
#
#
# $protocolSection$outcomesModule$secondaryOutcomes[[2]]
# $protocolSection$outcomesModule$secondaryOutcomes[[2]]$measure
# [1] "The changes in blood glucose level"
#
# $protocolSection$outcomesModule$secondaryOutcomes[[2]]$description
# [1] "The changes in blood glucose level after transplantation"
#
# $protocolSection$outcomesModule$secondaryOutcomes[[2]]$timeFrame
# [1] "24 weeks after treatment"
#
#
#
#
# $protocolSection$eligibilityModule
# $protocolSection$eligibilityModule$eligibilityCriteria
# [1] "Inclusion Criteria:\n\n1. Type 2 diabetes；\n2. The course of diabetes is 5-15 years;\n3. 20kg/m2≤body mass index (BMI)≤30 kg /m2；\n4. 7.5% ≤HbA1c≤10%；\n5. Insulin dose and other oral antidiabetic drugs doses should be stable over the 3 months prior to randomization.\n\nExclusion Criteria:\n\n1. Heavy allergic constitution or an allergy to any component used in cell culture.\n2. Being treated with drug (Glucocorticoids，Tricyclic Antidepressive Agents,etc.) affect the metabolism of glucose in the past 1 month;\n3. other causes of diabetes;\n4. All kinds of acute complications such as diabetic ketoacidosis and non-ketohyperosmotic syndrome were screened in the past 6 months;\n5. Having evidence of ongoing or frequent/severe hypoglycemia in the past 6 months;\n6. Severe cardiovascular and cerebral events：occurrence of heart failure NYHA Classification III or IV, myocardial infarction, cerebral infarction, cerebral hemorrhage within 6 months before the observation period;\n7. Patients with abnormal liver and kidney function: AST and ALT exceeding 2.5 times of the normal upper limit, and serum creatinine exceeding 1.5 mg/dl for men, exceeding 1.4 mg/dl for women;\n8. Positive results of HbsAg、Anti-HCV、HIV or syphilis;\n9. Patients suffering from other serious systemic diseases (such as malignancy, central nervous system,cardiovascular system, blood system, digestive system,endocrine system,respiratory system, genitourinary system, immune system and);\n10. Ongoing pregnancy or absence of effective contraception in women with childbearing potential;\n11. Patients who had received other stem cell therapy before screening."
#
# $protocolSection$eligibilityModule$healthyVolunteers
# [1] FALSE
#
# $protocolSection$eligibilityModule$sex
# [1] "ALL"
#
# $protocolSection$eligibilityModule$minimumAge
# [1] "30 Years"
#
# $protocolSection$eligibilityModule$maximumAge
# [1] "75 Years"
#
# $protocolSection$eligibilityModule$stdAges
# $protocolSection$eligibilityModule$stdAges[[1]]
# [1] "ADULT"
#
# $protocolSection$eligibilityModule$stdAges[[2]]
# [1] "OLDER_ADULT"
#
#
#
# $protocolSection$contactsLocationsModule
# $protocolSection$contactsLocationsModule$centralContacts
# $protocolSection$contactsLocationsModule$centralContacts[[1]]
# $protocolSection$contactsLocationsModule$centralContacts[[1]]$name
# [1] "wang congrong, doctor"
#
# $protocolSection$contactsLocationsModule$centralContacts[[1]]$role
# [1] "CONTACT"
#
# $protocolSection$contactsLocationsModule$centralContacts[[1]]$phone
# [1] "+86-021-38804518"
#
# $protocolSection$contactsLocationsModule$centralContacts[[1]]$email
# [1] "wcr601@163.com"
#
#
# $protocolSection$contactsLocationsModule$centralContacts[[2]]
# $protocolSection$contactsLocationsModule$centralContacts[[2]]$name
# [1] "liu zhongmin, doctor"
#
# $protocolSection$contactsLocationsModule$centralContacts[[2]]$role
# [1] "CONTACT"
#
# $protocolSection$contactsLocationsModule$centralContacts[[2]]$phone
# [1] "+86-021-38804518"
#
# $protocolSection$contactsLocationsModule$centralContacts[[2]]$email
# [1] "liu.zhongmin@tongji.edu.cn"
#
#
#
# $protocolSection$contactsLocationsModule$overallOfficials
# $protocolSection$contactsLocationsModule$overallOfficials[[1]]
# $protocolSection$contactsLocationsModule$overallOfficials[[1]]$name
# [1] "wang congrong, doctor"
#
# $protocolSection$contactsLocationsModule$overallOfficials[[1]]$affiliation
# [1] "Shanghai East Hospital, China"
#
# $protocolSection$contactsLocationsModule$overallOfficials[[1]]$role
# [1] "PRINCIPAL_INVESTIGATOR"
#
#
#
# $protocolSection$contactsLocationsModule$locations
# $protocolSection$contactsLocationsModule$locations[[1]]
# $protocolSection$contactsLocationsModule$locations[[1]]$facility
# [1] "Shanghai East Hospital, Shanghai Tongji University"
#
# $protocolSection$contactsLocationsModule$locations[[1]]$status
# [1] "RECRUITING"
#
# $protocolSection$contactsLocationsModule$locations[[1]]$city
# [1] "Shanghai"
#
# $protocolSection$contactsLocationsModule$locations[[1]]$state
# [1] "Shanghai Municipality"
#
# $protocolSection$contactsLocationsModule$locations[[1]]$zip
# [1] "200120"
#
# $protocolSection$contactsLocationsModule$locations[[1]]$country
# [1] "China"
#
# $protocolSection$contactsLocationsModule$locations[[1]]$contacts
# $protocolSection$contactsLocationsModule$locations[[1]]$contacts[[1]]
# $protocolSection$contactsLocationsModule$locations[[1]]$contacts[[1]]$name
# [1] "wang congrong, doctor"
#
# $protocolSection$contactsLocationsModule$locations[[1]]$contacts[[1]]$role
# [1] "CONTACT"
#
#
#
# $protocolSection$contactsLocationsModule$locations[[1]]$geoPoint
# $protocolSection$contactsLocationsModule$locations[[1]]$geoPoint$lat
# [1] 31.22222
#
# $protocolSection$contactsLocationsModule$locations[[1]]$geoPoint$lon
# [1] 121.4581
#
#
#
#
#
#
# $derivedSection
# $derivedSection$miscInfoModule
# $derivedSection$miscInfoModule$versionHolder
# [1] "2026-01-20"
#
#
# $derivedSection$conditionBrowseModule
# $derivedSection$conditionBrowseModule$meshes
# $derivedSection$conditionBrowseModule$meshes[[1]]
# $derivedSection$conditionBrowseModule$meshes[[1]]$id
# [1] "D003924"
#
# $derivedSection$conditionBrowseModule$meshes[[1]]$term
# [1] "Diabetes Mellitus, Type 2"
#
#
#
# $derivedSection$conditionBrowseModule$ancestors
# $derivedSection$conditionBrowseModule$ancestors[[1]]
# $derivedSection$conditionBrowseModule$ancestors[[1]]$id
# [1] "D003920"
#
# $derivedSection$conditionBrowseModule$ancestors[[1]]$term
# [1] "Diabetes Mellitus"
#
#
# $derivedSection$conditionBrowseModule$ancestors[[2]]
# $derivedSection$conditionBrowseModule$ancestors[[2]]$id
# [1] "D044882"
#
# $derivedSection$conditionBrowseModule$ancestors[[2]]$term
# [1] "Glucose Metabolism Disorders"
#
#
# $derivedSection$conditionBrowseModule$ancestors[[3]]
# $derivedSection$conditionBrowseModule$ancestors[[3]]$id
# [1] "D008659"
#
# $derivedSection$conditionBrowseModule$ancestors[[3]]$term
# [1] "Metabolic Diseases"
#
#
# $derivedSection$conditionBrowseModule$ancestors[[4]]
# $derivedSection$conditionBrowseModule$ancestors[[4]]$id
# [1] "D009750"
#
# $derivedSection$conditionBrowseModule$ancestors[[4]]$term
# [1] "Nutritional and Metabolic Diseases"
#
#
# $derivedSection$conditionBrowseModule$ancestors[[5]]
# $derivedSection$conditionBrowseModule$ancestors[[5]]$id
# [1] "D004700"
#
# $derivedSection$conditionBrowseModule$ancestors[[5]]$term
# [1] "Endocrine System Diseases"
#
#
#
#
# $derivedSection$interventionBrowseModule
# $derivedSection$interventionBrowseModule$meshes
# $derivedSection$interventionBrowseModule$meshes[[1]]
# $derivedSection$interventionBrowseModule$meshes[[1]]$id
# [1] "D012965"
#
# $derivedSection$interventionBrowseModule$meshes[[1]]$term
# [1] "Sodium Chloride"
#
#
#
# $derivedSection$interventionBrowseModule$ancestors
# $derivedSection$interventionBrowseModule$ancestors[[1]]
# $derivedSection$interventionBrowseModule$ancestors[[1]]$id
# [1] "D002712"
#
# $derivedSection$interventionBrowseModule$ancestors[[1]]$term
# [1] "Chlorides"
#
#
# $derivedSection$interventionBrowseModule$ancestors[[2]]
# $derivedSection$interventionBrowseModule$ancestors[[2]]$id
# [1] "D006851"
#
# $derivedSection$interventionBrowseModule$ancestors[[2]]$term
# [1] "Hydrochloric Acid"
#
#
# $derivedSection$interventionBrowseModule$ancestors[[3]]
# $derivedSection$interventionBrowseModule$ancestors[[3]]$id
# [1] "D017606"
#
# $derivedSection$interventionBrowseModule$ancestors[[3]]$term
# [1] "Chlorine Compounds"
#
#
# $derivedSection$interventionBrowseModule$ancestors[[4]]
# $derivedSection$interventionBrowseModule$ancestors[[4]]$id
# [1] "D007287"
#
# $derivedSection$interventionBrowseModule$ancestors[[4]]$term
# [1] "Inorganic Chemicals"
#
#
# $derivedSection$interventionBrowseModule$ancestors[[5]]
# $derivedSection$interventionBrowseModule$ancestors[[5]]$id
# [1] "D017670"
#
# $derivedSection$interventionBrowseModule$ancestors[[5]]$term
# [1] "Sodium Compounds"
#
#
#
#
#
# $hasResults
# [1] FALSE

# %%
for (i in seq_along(studies)) {
  study <- studies[[i]]

  nct_id <- study$protocolSection$identificationModule$nctId
  title  <- study$protocolSection$identificationModule$briefTitle
  status <- study$protocolSection$statusModule$overallStatus

  cat("\n------------------------\n")
  cat("NCT ID:", nct_id, "\n")
  cat("Title:", title, "\n")
  cat("Status:", status, "\n")
}
# Out:
# ------------------------
# NCT ID: NCT04441658
# Title: Efficacy and Safety of Umbilical Cord Mesenchymal Stem Cells Transplantation in Patients With Type 2 Diabetes Mellitus
# Status: UNKNOWN
#
# ------------------------
# NCT ID: NCT03162926
# Title: A Safety and Tolerability Study of VC-02™ Combination Product in Subjects With Type 1 Diabetes Mellitus
# Status: COMPLETED
#
# ------------------------
# NCT ID: NCT03797885
# Title: A Study of People With Type 2 Diabetes Who Have Diseases That Affect the Heart and Blood Vessels. The Study Will Also Look at the Treatment of a Group of These People in Hospitals in Portugal
# Status: COMPLETED
#
# ------------------------
# NCT ID: NCT01373476
# Title: Multicentre, Randomized, Controlled Trial of Qideng Mingmu Capsule in The Treatment of Diabetic Retinopathy
# Status: COMPLETED
#
# ------------------------
# NCT ID: NCT01686568
# Title: Omega-3 Fatty Acids and Insulin Sensitivity
# Status: COMPLETED

# %% [markdown]
# ## 21-Jan-2026
#
# Collaborated with team members and threw around some ideas:

# %%
library(httr)
library(jsonlite)
library(dplyr)
library(purrr)
library(tibble)

`%||%` <- function(x, y) if (is.null(x)) y else x

ct_search_studies <- function(query = NULL,
                              condition = NULL,
                              intervention = NULL,
                              page_size = 100,
                              page_token = NULL) {

  base_url <- "https://clinicaltrials.gov/api/v2/studies"

  # Build query parameters
  params <- list(
    pageSize = page_size,
    format = "json"
  )

  if (!is.null(query)) {
    params[["query.term"]] <- query
  }

  if (!is.null(condition)) {
    params[["query.cond"]] <- condition
  }

  if (!is.null(intervention)) {
    params[["query.intr"]] <- intervention
  }

  if (!is.null(page_token)) {
    params[["pageToken"]] <- page_token
  }

  # Send request
  resp <- GET(base_url, query = params)
  stop_for_status(resp)

  txt <- content(resp, as = "text", encoding = "UTF-8")
  json <- fromJSON(txt, simplifyVector = FALSE)

  studies <- json$studies %||% list()

  # Extract a few useful fields into a tidy table
  out <- tibble(
    nct_id = map_chr(studies, ~ .x$protocolSection$identificationModule$nctId %||% NA_character_),
    title  = map_chr(studies, ~ .x$protocolSection$identificationModule$briefTitle %||% NA_character_),
    status = map_chr(studies, ~ .x$protocolSection$statusModule$overallStatus %||% NA_character_),
    phase  = map_chr(studies, ~ paste(.x$protocolSection$designModule$phaseList$phase, collapse = ", ") %||% NA_character_),
    start_date = map_chr(studies, ~ .x$protocolSection$statusModule$startDateStruct$date %||% NA_character_)
  )

  list(
    data = out,
    next_page_token = json$nextPageToken %||% NULL,
    total_count = json$totalCount %||% NA_integer_
  )
}
# Out:
# Warning message:
# "package 'httr' was built under R version 4.5.2"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: 'purrr'
#
#
# The following object is masked from 'package:jsonlite':
#
#     flatten

# %%
res <- ct_search_studies(condition = "diabetes", page_size = 20)

res$data
# Out:
#    nct_id
# 1  NCT02951260
# 2  NCT00286624
# 3  NCT00859079
# 4  NCT00480779
# 5  NCT03885362
# 6  NCT04089462
# 7  NCT03810846
# 8  NCT00136188
# 9  NCT04919603
# 10 NCT00762242
# 11 NCT00922194
# 12 NCT05295329
# 13 NCT05870202
# 14 NCT05881837
# 15 NCT05203575
# 16 NCT05548218
# 17 NCT04403789
# 18 NCT00296374
# 19 NCT00353990
# 20 NCT03603990
#    title
# 1  The Effects of Metformin on Self-selected Exercise Intensity, Physical Fitness and Exercise-induced AMPK-activation
# 2  Anti-Thymocyte Globulin, Cyclosporine, and RAD in Islet Transplantation
# 3  Efficacy of GLP-1 Infusion in Comparison to an Insulin Infusion Protocol to Reach Normoglycemia Type 2 Diabetic Patients
# 4  Evaluation of Group Lifestyle Balance DVD in Primary Care Practice
# 5  Assessment of the Accuracy of Continuous Glucose Sensors in People With Diabetes Undergoing Haemodialysis
# 6  Effects of Frequency and Duration of Exercise in People With Type 1 Diabetes A Randomized Crossover Study
# 7  Feasibility and Safety of Walking Football in Patients With Type 2 Diabetes
# 8  Nitric Oxide (NO) Activity and Diabetic Nephropathy
# 9  Impact of Exercise Intervention on the Phenome
# 10 Metabolomic Profiling of Novel Mediators of Vascular Function
# 11 Metformin in Overweight Type 2 Diabetes Mellitus
# 12 Effect of Compound Danshen Dripping Pills on Diabetic Patients With Coronary Microcirculation Disturbance
# 13 Treatment Burden Screening Questionnaire Pilot Study
# 14 Efficacy and Safety of HRS9531 Injection in Obese Subjects Without Diabetes
# 15 Building a Behavioural Intervention Programme to Improve Self-Management of Diabetes
# 16 Care Companion Diabetes
# 17 Effects of a Workplace Exercise Intervention on Cardio-Metabolic Health
# 18 Prospective Evaluation of Proteinuria and Renal Function in Diabetic Patients With Progressive Renal Disease
# 19 Bioavailability of Insulin Administered in Duodenum
# 20 Effect of Vitrectomy on the Evolution of Refractory Diabetic Macular Edema
#    status     phase start_date
# 1  COMPLETED        2016-10
# 2  COMPLETED        2003-03
# 3  COMPLETED        2006-06
# 4  COMPLETED        2007-06
# 5  COMPLETED        2019-12-11
# 6  COMPLETED        2019-09-30
# 7  COMPLETED        2018-09-17
# 8  COMPLETED        2009-08
# 9  UNKNOWN          2021-06-15
# 10 TERMINATED       2007-05
# 11 COMPLETED        2006-02
# 12 UNKNOWN          2022-04-01
# 13 COMPLETED        2023-03-07
# 14 COMPLETED        2023-06-13
# 15 UNKNOWN          2022-03-28
# 16 COMPLETED        2022-08-15
# 17 COMPLETED        2021-03-28
# 18 COMPLETED        2006-02
# 19 COMPLETED        2006-08
# 20 WITHDRAWN        2018-09-01
