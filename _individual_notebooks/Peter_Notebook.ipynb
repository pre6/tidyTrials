# %% [markdown]
# # Jan 18th
#
# Research & API exploration:
# - Researched the ClinicalTrials.gov v2 API structure
# - Identified supported query parameters and advanced search syntax
# - Analyzed API response schema and core output modules (7 study modules)
# - Identify important fields
# - Explore pagination strategy for large-scale data pulls

# %% [markdown]
# # Jan 22nd
#
# - Implemented `trials_fetch()` to query the **ClinicalTrials.gov v2 API** with automatic pagination.
# - Added filtering support via advanced query syntax:
#   - `phase`
#   - `country`
#   - date range (`from_date`, `to_date`) with a selectable `date_filter` field.
#
# **Notable implementation details:**
#
# - **Date parsing & validation:** Enforced strict user input format (`YYYY-MM-DD`) to avoid ambiguous or invalid dates; validated date bounds and handled edge cases (e.g., `from_date` later than `to_date`). Converted validated dates into the API’s advanced query syntax using
#   ```r
#   paste0("AREA[", date_filter, "]RANGE[", from_date, ",", to_date, "]")
# - **Also include date_filter selection** (e.g., filtering by study start date vs. completion date).
# - **Maximum record enforcement:** Implemented a strict upper bound on the total number of records fetched by maintaining a running counter across paginated requests and cropping the final page of results to avoid exceeding the limit:
# ```data <- .fetch_page(url, params)
# studies <- data$studies
#
# if (is.null(studies) || length(studies) == 0) break
#
# remaining <- max_records - fetched
# to_take   <- min(length(studies), remaining)
# studies   <- studies[seq_len(to_take)]```

# %%
suppressWarnings(devtools::load_all())
spec <- list(
  query = "cancer",
  max_records = 10,
  phase = "Phase 2",
  country = "Canada",
  from_date = "2022-01-01",
  to_date = "2023-01-01",
  date_filter = "StartDate"
)
result <- trials_run_spec(spec)

# %%
# Show that 10 records were retrieved
result[2]
# Out:
# $meta
# $meta$query
# [1] "cancer"
#
# $meta$max_records
# [1] 10
#
# $meta$fetched
# [1] 10
#
# $meta$phase
# [1] "Phase 2"
#
# $meta$country
# [1] "Canada"
#
# $meta$from_date
# [1] "2022-01-01"
#
# $meta$to_date
# [1] "2023-01-01"
#
# $meta$date_filter
# [1] "StartDate"

# %% [markdown]
# # Feb 1st

# %% [markdown]
# JSON Streaming Support
#
# Implemented the ability to save results directly to a JSON file.
#
# - This can be enabled via: `trial_fetch(save_json = TRUE, json_file = "filename.json")`
#
# - This feature is intended for users who want to collect large volumes of data.
#     - Without JSON streaming, all results would be stored in memory, which can lead to memory exhaustion for large queries.
#     - To avoid this, downloading to JSON is implemented using data streaming, where small chunks of data are written incrementally to disk instead of being kept in memory.
#
# ```
# while (fetched < max_records) {
#   data <- .fetch_page(url, params)
#   studies <- data$studies
#
#   if (save_json) {
#     for (s in studies) {
#       if (!first) writeLines(",", con)  # avoid writing a comma before the first entry
#
#       writeLines(
#         jsonlite::toJSON(s, auto_unbox = TRUE, null = "null"),
#         con
#       )
#
#       first <- FALSE
#       fetched <- fetched + 1L
#     }
#   }
# }
# ```
#
# Core idea
#    - Fetch studies in batches (up to 1000 records per API request).
#    - Write each study directly to a JSON file as it is retrieved.
#    - Flush data to disk incrementally instead of accumulating it in memory.
#    - This allows users to download thousands of records safely without risking memory overload.

# %%
json_spec <- list(
    query = "cancer",
    max_records = 2000,
    phase = "Phase 2",
    country = "Canada",
    from_date = "2016-01-01",
    to_date = "2023-01-01",
    date_filter = "StartDate",
    save_json = TRUE,
    json_file = "cancer_trials.json"  
    )
json_result <- trials_run_spec(json_spec)
# Out:
# $query
# [1] "cancer"
#
# $max_records
# [1] 2000
#
# $fetched
# [1] 920
#
# $phase
# [1] "Phase 2"
#
# $country
# [1] "Canada"
#
# $from_date
# [1] "2016-01-01"
#
# $to_date
# [1] "2023-01-01"
#
# $date_filter
# [1] "StartDate"
#
# [1] "Saving JSON output to cancer_trials.json"

# %%
library(jsonlite)
data <- fromJSON("cancer_trials.json", simplifyVector = FALSE)

# %%
str(data[[1]], max.level = 3)
# Out:
# List of 5
#  $ protocolSection:List of 13
#   ..$ identificationModule      :List of 6
#   .. ..$ nctId           : chr "NCT04649359"
#   .. ..$ orgStudyIdInfo  :List of 1
#   .. ..$ secondaryIdInfos:List of 2
#   .. ..$ organization    :List of 2
#   .. ..$ briefTitle      : chr "MagnetisMM-3: Study Of Elranatamab (PF-06863135) Monotherapy in Participants With Multiple Myeloma Who Are Refr"| __truncated__
#   .. ..$ officialTitle   : chr "MAGNETISMM-3 AN OPEN-LABEL, MULTICENTER, NON-RANDOMIZED PHASE 2 STUDY OF ELRANATAMAB (PF-06863135) MONOTHERAPY "| __truncated__
#   ..$ statusModule              :List of 13
#   .. ..$ statusVerifiedDate         : chr "2025-11"
#   .. ..$ overallStatus              : chr "ACTIVE_NOT_RECRUITING"
#   .. ..$ startDateStruct            :List of 2
#   .. ..$ primaryCompletionDateStruct:List of 2
#   .. ..$ completionDateStruct       :List of 2
#   .. ..$ studyFirstSubmitDate       : chr "2020-11-06"
#   .. ..$ studyFirstSubmitQcDate     : chr "2020-11-24"
#   .. ..$ studyFirstPostDateStruct   :List of 2
#   .. ..$ resultsFirstSubmitDate     : chr "2023-06-15"
#   .. ..$ resultsFirstSubmitQcDate   : chr "2023-10-04"
#   .. ..$ resultsFirstPostDateStruct :List of 2
#   .. ..$ lastUpdateSubmitDate       : chr "2025-11-17"
#   .. ..$ lastUpdatePostDateStruct   :List of 2
#   ..$ sponsorCollaboratorsModule:List of 2
#   .. ..$ responsibleParty:List of 1
#   .. ..$ leadSponsor     :List of 2
#   ..$ oversightModule           :List of 3
#   .. ..$ oversightHasDmc     : logi TRUE
#   .. ..$ isFdaRegulatedDrug  : logi TRUE
#   .. ..$ isFdaRegulatedDevice: logi FALSE
#   ..$ descriptionModule         :List of 1
#   .. ..$ briefSummary: chr "The purpose of the study is to evaluate whether single-agent Elranatamab (PF-06863135) can provide clinical ben"| __truncated__
#   ..$ conditionsModule          :List of 2
#   .. ..$ conditions:List of 1
#   .. ..$ keywords  :List of 11
#   ..$ designModule              :List of 4
#   .. ..$ studyType     : chr "INTERVENTIONAL"
#   .. ..$ phases        :List of 1
#   .. ..$ designInfo    :List of 4
#   .. ..$ enrollmentInfo:List of 2
#   ..$ armsInterventionsModule   :List of 2
#   .. ..$ armGroups    :List of 2
#   .. ..$ interventions:List of 1
#   ..$ outcomesModule            :List of 2
#   .. ..$ primaryOutcomes  :List of 1
#   .. ..$ secondaryOutcomes:List of 21
#   ..$ eligibilityModule         :List of 5
#   .. ..$ eligibilityCriteria: chr "Inclusion Criteria:\n\n* Diagnosis of multiple myeloma (IMWG criteria, Rajkumar et al, 2014)\n* Measurable dise"| __truncated__
#   .. ..$ healthyVolunteers  : logi FALSE
#   .. ..$ sex                : chr "ALL"
#   .. ..$ minimumAge         : chr "18 Years"
#   .. ..$ stdAges            :List of 2
#   ..$ contactsLocationsModule   :List of 2
#   .. ..$ overallOfficials:List of 1
#   .. ..$ locations       :List of 87
#   ..$ referencesModule          :List of 2
#   .. ..$ references  :List of 7
#   .. ..$ seeAlsoLinks:List of 1
#   ..$ ipdSharingStatementModule :List of 3
#   .. ..$ ipdSharing : chr "YES"
#   .. ..$ description: chr "Pfizer will provide access to individual de-identified participant data and related study documents (e.g. proto"| __truncated__
#   .. ..$ url        : chr "https://www.pfizer.com/science/clinical_trials/trial_data_and_results/data_requests"
#  $ resultsSection :List of 5
#   ..$ participantFlowModule        :List of 4
#   .. ..$ preAssignmentDetails: chr "A total of 187 participants were enrolled and assigned to study treatment. Results are reported at primary comp"| __truncated__
#   .. ..$ recruitmentDetails  : chr "Participants with relapsed/refractory multiple myeloma (RRMM), who were refractory to at least 1 proteasome inh"| __truncated__
#   .. ..$ groups              :List of 2
#   .. ..$ periods             :List of 1
#   ..$ baselineCharacteristicsModule:List of 4
#   .. ..$ populationDescription: chr "Safety analysis set in each cohort included all enrolled participants in the respective cohort who received at "| __truncated__
#   .. ..$ groups               :List of 3
#   .. ..$ denoms               :List of 1
#   .. ..$ measures             :List of 4
#   ..$ outcomeMeasuresModule        :List of 1
#   .. ..$ outcomeMeasures:List of 22
#   ..$ adverseEventsModule          :List of 6
#   .. ..$ frequencyThreshold: chr "5"
#   .. ..$ timeFrame         : chr "From the date of first dose up to 90 days after last dose or start of new anticancer therapy whichever occurred"| __truncated__
#   .. ..$ description       : chr "Same event may appear as both non-SAE and SAE. What is presented are distinct events. An event may be categoriz"| __truncated__
#   .. ..$ eventGroups       :List of 2
#   .. ..$ seriousEvents     :List of 143
#   .. ..$ otherEvents       :List of 65
#   ..$ moreInfoModule               :List of 3
#   .. ..$ limitationsAndCaveats:List of 1
#   .. ..$ certainAgreement     :List of 4
#   .. ..$ pointOfContact       :List of 4
#  $ documentSection:List of 1
#   ..$ largeDocumentModule:List of 1
#   .. ..$ largeDocs:List of 2
#  $ derivedSection :List of 2
#   ..$ miscInfoModule       :List of 2
#   .. ..$ versionHolder     : chr "2026-02-03"
#   .. ..$ submissionTracking:List of 1
#   ..$ conditionBrowseModule:List of 2
#   .. ..$ meshes   :List of 2
#   .. ..$ ancestors:List of 13
#  $ hasResults     : logi TRUE
